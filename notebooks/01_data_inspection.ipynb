# %% [markdown]
# # 01 — Data inspection and repeated-measures structure
#
# The first task is not modeling. It is understanding what one row represents, who the patient is, and how many observations belong to each patient.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load the UCI file
#
# Place the downloaded `parkinsons_updrs.data` file in `data/raw/` before running this section.

# %%
# TODO: confirm the exact local file name and separator from the UCI source record.
# Example starting point:
# df = pd.read_csv('../data/raw/parkinsons_updrs.data')

# df.head()

# %% [markdown]
# ## First questions
#
# - How many rows and columns are there?
# - What is the patient identifier?
# - How many observations belong to each patient?
# - Are there duplicated rows?
# - What is the target variable?
# - What does a random row split assume about independence?
